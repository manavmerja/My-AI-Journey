# %%
import google.generativeai as genai

# 1. Setup (Key wahi purani wali)
GOOGLE_API_KEY = "Your APi KEY" 
genai.configure(api_key=GOOGLE_API_KEY)

print("🔍 Searching for available models...")

# 2. List Models (Check karna ki kon available hai)
for m in genai.list_models():
  # Hum sirf wo models dhund rahe hain jo 'Content Generate' kar sakein (Chat wale)
  if 'generateContent' in m.supported_generation_methods:
    print(f"- {m.name}")
# Out:
# 🔍 Searching for available models...
# - models/gemini-2.5-flash
# - models/gemini-2.5-pro
# - models/gemini-2.0-flash-exp
# - models/gemini-2.0-flash
# - models/gemini-2.0-flash-001
# - models/gemini-2.0-flash-exp-image-generation
# - models/gemini-2.0-flash-lite-001
# - models/gemini-2.0-flash-lite
# - models/gemini-2.0-flash-lite-preview-02-05
# - models/gemini-2.0-flash-lite-preview
# - models/gemini-2.0-pro-exp
# - models/gemini-2.0-pro-exp-02-05
# - models/gemini-exp-1206
# - models/gemini-2.5-flash-preview-tts
# - models/gemini-2.5-pro-preview-tts
# - models/gemma-3-1b-it
# - models/gemma-3-4b-it
# - models/gemma-3-12b-it
# - models/gemma-3-27b-it
# - models/gemma-3n-e4b-it
# - models/gemma-3n-e2b-it
# - models/gemini-flash-latest
# - models/gemini-flash-lite-latest
# - models/gemini-pro-latest
# - models/gemini-2.5-flash-lite
# - models/gemini-2.5-flash-image-preview
# - models/gemini-2.5-flash-image
# - models/gemini-2.5-flash-preview-09-2025
# ...

# %%
import google.generativeai as genai

# 1. Setup (Key wahi purani wali)
GOOGLE_API_KEY = "Your Api Key" 
genai.configure(api_key=GOOGLE_API_KEY)

# 2. Model Selection (Updated Name) 🔄
# Humne list se 'models/gemini-2.0-flash' chuna hai
model = genai.GenerativeModel('gemini-2.0-flash')

# 3. Prompting
response = model.generate_content("Explain AI to a 5 year old in a funny way.")

# 4. Result
print(response.text)
# Out:
# Okay, imagine you have a really, really smart parrot, but instead of feathers, it has wires and a screen. This parrot is named Arty-ficial Intelligence!
#
# Arty is SO smart, you can show him pictures of cookies, and he'll learn what cookies are. Show him enough cookie pictures, and he can even draw his OWN cookie! He might draw one with rainbow sprinkles and gummy worms - because Arty's still learning!
#
# He's like a super-duper learner. You tell him "Jump!", and he tries to jump. If he falls on his robot bum, he remembers and next time he'll try harder to stay standing.
#
# So, AI is like a super-smart parrot (with wires!) that can learn new things, try new things, and sometimes be a little bit silly while doing it! Just don't ask him to clean your room, he's still working on that!
